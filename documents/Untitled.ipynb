# %%
import os
import math
import re
import nltk
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Delta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Delta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Delta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
STOPWORDS = set(stopwords.words('english'))
LEMMATIZER = WordNetLemmatizer()

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)
    tokens = word_tokenize(text)
    return [LEMMATIZER.lemmatize(word) for word in tokens if word not in STOPWORDS]

def term_frequency(term, document):
    return document.count(term) / len(document)

def inverse_document_frequency(term, all_documents):
    num_docs_containing_term = sum(1 for doc in all_documents if term in doc)
    return math.log(len(all_documents) / (num_docs_containing_term)) if num_docs_containing_term > 0 else 0

# %%
def compute_tfidf(document, all_documents, vocab):
    tfidf_vector = []
    for term in vocab:
        tf = term_frequency(term, document)
        idf = inverse_document_frequency(term, all_documents)
        tfidf_vector.append(tf * idf)
    return np.array(tfidf_vector)

def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2) if norm_vec1 > 0 and norm_vec2 > 0 else 0

# %%
def load_txt_files(folder_path):
    documents = []
    filenames = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                content = file.read()
                documents.append(clean_text(content))
                filenames.append(filename)
    return documents, filenames

def calculate_precision_at_k(relevant_docs, ranked_docs, k):
    if not ranked_docs:
        return 0.0
    top_k_docs = ranked_docs[:k]
    relevant_retrieved = sum(1 for doc in top_k_docs if doc[0] in relevant_docs)
    return relevant_retrieved / k

# %%
queries = [
    "Latest developments?",
    "Sanctions impact 2024?",
    "International response?",
    "Civilians affected?",
    "NATO's role?",
    "Global security implications?",
    "Energy price influence?",
    "Humanitarian efforts?",
    "Military strategies?",
    "Cultural impacts?",
    "Economic changes?",
    "Historical roots?",
    "NATO influence?",
    "Agricultural impact?",
    "Natural resources?",
    "Russian culture?",
    "Geopolitical implications?",
    "Humanitarian challenges?"
]

# %%
def main():
    folder_path = r'C:\Users\Delta\Documents\VSM-Precision\documents'
    documents, filenames = load_txt_files(folder_path)
    for query in queries:
        cleaned_query = clean_text(query)
        vocab = sorted(set(word for doc in documents + [cleaned_query] for word in doc))
        query_vector = compute_tfidf(cleaned_query, documents, vocab)
        doc_vectors = [compute_tfidf(doc, documents, vocab) for doc in documents]
        similarities = [(filenames[i], cosine_similarity(query_vector, doc_vector)) for i, doc_vector in enumerate(doc_vectors)]
        similarities = sorted(similarities, key=lambda x: x[1], reverse=True)
        k = 5
        relevant_docs = set(filenames)
        precision_at_k = calculate_precision_at_k(relevant_docs, similarities, k)
        with open("sahas_results.txt", "a") as f:
            f.write(f"Results for query: '{query}'\n")
            f.write(f"Precision@{k}: {precision_at_k:.4f}\n")
            for title, similarity in similarities[:k]:
                f.write(f"Document: {title}, Similarity: {similarity:.4f}\n")
            f.write("\n")
    print("Results written to 'sahas_results.txt'.")
    with open('sahas_results.txt', 'r') as f:
        content = f.readlines()
        for line in content:
            if line.startswith("Document:"):
                parts = line.split(", Similarity:")
                filename = parts[0][10:]
                similarity_score = parts[1].strip()
                if len(filename) > 48:
                    formatted_filename = f"{filename[:25]}...{filename[-25:]}, Similarity: {similarity_score}"
                else:
                    formatted_filename = line.strip()
                print(formatted_filename)
            else:
                print(line.strip())

if __name__ == "__main__":
    main()
# Out:
# Results written to 'sahas_results.txt'.
# Results for query: 'Latest developments?'
# Precision@5: 1.0000
# Document: Putin.txt, Similarity: 0.0358
# Document: Ukraine's EU Membership Aspirations.txt, Similarity: 0.0299
# Document: evaluation_results.txt, Similarity: 0.0203
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0202
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0105
#
# Results for query: 'Sanctions impact 2024?'
# Precision@5: 1.0000
# Document: evaluation_results.txt, Similarity: 0.0549
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0487
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0467
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0324
# Document: GlobalView.txt, Similarity: 0.0265
#
# Results for query: 'International response?'
# Precision@5: 1.0000
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0644
# Document: HelloRussia.txt, Similarity: 0.0228
# Document: evaluation_results.txt, Similarity: 0.0181
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0154
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0147
#
# Results for query: 'Civilians affected?'
# Precision@5: 1.0000
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0707
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0650
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0433
# Document: HelloRussia.txt, Similarity: 0.0358
# Document: evaluation_results.txt, Similarity: 0.0216
#
# Results for query: 'NATO's role?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.1916
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0675
# Document: HelloRussia.txt, Similarity: 0.0493
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.0422
# Document: evaluation_results.txt, Similarity: 0.0369
#
# Results for query: 'Global security implications?'
# Precision@5: 1.0000
# Document: GlobalView.txt, Similarity: 0.1112
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0862
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0728
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.0717
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.0480
#
# Results for query: 'Energy price influence?'
# Precision@5: 1.0000
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.2549
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.1200
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.1090
# Document: GlobalView.txt, Similarity: 0.0438
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.0303
#
# Results for query: 'Humanitarian efforts?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1414
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.1071
# Document: Cultural Heritage of Ukraine.txt, Similarity: 0.0394
# Document: HelloRussia.txt, Similarity: 0.0387
# Document: evaluation_results.txt, Similarity: 0.0266
#
# Results for query: 'Military strategies?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.1279
# Document: HelloRussia.txt, Similarity: 0.1090
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0706
# Document: Putin.txt, Similarity: 0.0597
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0351
#
# Results for query: 'Cultural impacts?'
# Precision@5: 1.0000
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.1195
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.1040
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0941
# Historical Context of Rus...sia-Ukraine Relations.txt, Similarity: 0.0714
# Document: evaluation_results.txt, Similarity: 0.0693
#
# Results for query: 'Economic changes?'
# Precision@5: 1.0000
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0661
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0532
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.0363
# Document: Ukraine's EU Membership Aspirations.txt, Similarity: 0.0262
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0177
#
# Results for query: 'Historical roots?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1186
# Document: Russia's History and Modern Geopolitics.txt, Similarity: 0.0880
# Historical Context of Rus...sia-Ukraine Relations.txt, Similarity: 0.0612
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0317
# Document: Russian Culture and National Identity.txt, Similarity: 0.0238
#
# Results for query: 'NATO influence?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.2285
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0641
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0473
# Document: HelloRussia.txt, Similarity: 0.0468
# Document: evaluation_results.txt, Similarity: 0.0399
#
# Results for query: 'Agricultural impact?'
# Precision@5: 1.0000
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.2514
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0853
# Document: evaluation_results.txt, Similarity: 0.0647
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0613
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0569
#
# Results for query: 'Natural resources?'
# Precision@5: 1.0000
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.4261
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.4157
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.1065
# Document: evaluation_results.txt, Similarity: 0.0552
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0396
#
# Results for query: 'Russian culture?'
# Precision@5: 1.0000
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.1977
# Document: Russian Culture and National Identity.txt, Similarity: 0.1761
# Historical Context of Rus...sia-Ukraine Relations.txt, Similarity: 0.0392
# Document: HelloRussia.txt, Similarity: 0.0340
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0326
#
# Results for query: 'Geopolitical implications?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1177
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0752
# Document: GlobalView.txt, Similarity: 0.0618
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0398
# Document: Russia's History and Modern Geopolitics.txt, Similarity: 0.0369
#
# Results for query: 'Humanitarian challenges?'
# Precision@5: 1.0000
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.1151
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1106
# Document: HelloRussia.txt, Similarity: 0.0307
# Document: evaluation_results.txt, Similarity: 0.0259
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0044
#
# Results for query: 'Latest developments?'
# Precision@5: 1.0000
# Document: Putin.txt, Similarity: 0.0310
# Document: Ukraine's EU Membership Aspirations.txt, Similarity: 0.0296
# Document: evaluation_results.txt, Similarity: 0.0210
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0202
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0102
#
# Results for query: 'Sanctions impact 2024?'
# Precision@5: 1.0000
# Document: evaluation_results.txt, Similarity: 0.0586
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0469
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0445
# Document: sahas_results.txt, Similarity: 0.0421
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0308
#
# Results for query: 'International response?'
# Precision@5: 1.0000
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0575
# Document: HelloRussia.txt, Similarity: 0.0204
# Document: evaluation_results.txt, Similarity: 0.0193
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0143
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0141
#
# Results for query: 'Civilians affected?'
# Precision@5: 1.0000
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0648
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0601
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0395
# Document: HelloRussia.txt, Similarity: 0.0294
# Document: evaluation_results.txt, Similarity: 0.0224
#
# Results for query: 'NATO's role?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.1787
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0614
# Document: HelloRussia.txt, Similarity: 0.0442
# Document: evaluation_results.txt, Similarity: 0.0407
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.0393
#
# Results for query: 'Global security implications?'
# Precision@5: 1.0000
# Document: GlobalView.txt, Similarity: 0.1003
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0798
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.0673
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0651
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.0465
#
# Results for query: 'Energy price influence?'
# Precision@5: 1.0000
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.2367
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.1110
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.1026
# Document: GlobalView.txt, Similarity: 0.0370
# Document: evaluation_results.txt, Similarity: 0.0299
#
# Results for query: 'Humanitarian efforts?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1273
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0942
# Document: Cultural Heritage of Ukraine.txt, Similarity: 0.0361
# Document: HelloRussia.txt, Similarity: 0.0344
# Document: evaluation_results.txt, Similarity: 0.0286
#
# Results for query: 'Military strategies?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.1212
# Document: HelloRussia.txt, Similarity: 0.0979
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0641
# Document: Putin.txt, Similarity: 0.0538
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0328
#
# Results for query: 'Cultural impacts?'
# Precision@5: 1.0000
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.1120
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0929
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0832
# Document: evaluation_results.txt, Similarity: 0.0744
# Document: sahas_results.txt, Similarity: 0.0696
#
# Results for query: 'Economic changes?'
# Precision@5: 1.0000
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0603
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0524
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.0364
# Document: Ukraine's EU Membership Aspirations.txt, Similarity: 0.0262
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0179
#
# Results for query: 'Historical roots?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1027
# Document: Russia's History and Modern Geopolitics.txt, Similarity: 0.0842
# Historical Context of Rus...sia-Ukraine Relations.txt, Similarity: 0.0542
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0304
# Document: Russian Culture and National Identity.txt, Similarity: 0.0227
#
# Results for query: 'NATO influence?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.2141
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0584
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0442
# Document: evaluation_results.txt, Similarity: 0.0439
# Document: HelloRussia.txt, Similarity: 0.0420
#
# Results for query: 'Latest developments?'
# Precision@5: 1.0000
# Document: Putin.txt, Similarity: 0.0310
# Document: Ukraine's EU Membership Aspirations.txt, Similarity: 0.0296
# Document: evaluation_results.txt, Similarity: 0.0210
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0202
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0102
#
# Results for query: 'Sanctions impact 2024?'
# Precision@5: 1.0000
# Document: evaluation_results.txt, Similarity: 0.0586
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0469
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0445
# Document: sahas_results.txt, Similarity: 0.0437
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0308
#
# Results for query: 'International response?'
# Precision@5: 1.0000
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0575
# Document: HelloRussia.txt, Similarity: 0.0204
# Document: evaluation_results.txt, Similarity: 0.0193
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0143
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0141
#
# Results for query: 'Civilians affected?'
# Precision@5: 1.0000
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0648
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0601
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0395
# Document: HelloRussia.txt, Similarity: 0.0294
# Document: evaluation_results.txt, Similarity: 0.0224
#
# Results for query: 'NATO's role?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.1787
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0614
# Document: HelloRussia.txt, Similarity: 0.0442
# Document: evaluation_results.txt, Similarity: 0.0407
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.0393
#
# Results for query: 'Global security implications?'
# Precision@5: 1.0000
# Document: GlobalView.txt, Similarity: 0.1003
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0798
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.0673
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0651
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.0465
#
# Results for query: 'Energy price influence?'
# Precision@5: 1.0000
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.2367
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.1110
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.1026
# Document: GlobalView.txt, Similarity: 0.0370
# Document: evaluation_results.txt, Similarity: 0.0299
#
# Results for query: 'Humanitarian efforts?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1273
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0942
# Document: Cultural Heritage of Ukraine.txt, Similarity: 0.0361
# Document: HelloRussia.txt, Similarity: 0.0344
# Document: evaluation_results.txt, Similarity: 0.0286
#
# Results for query: 'Military strategies?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.1212
# Document: HelloRussia.txt, Similarity: 0.0979
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0641
# Document: Putin.txt, Similarity: 0.0538
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0328
#
# Results for query: 'Cultural impacts?'
# Precision@5: 1.0000
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.1120
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.0929
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0832
# Document: evaluation_results.txt, Similarity: 0.0744
# Document: sahas_results.txt, Similarity: 0.0705
#
# Results for query: 'Economic changes?'
# Precision@5: 1.0000
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0603
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0524
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.0364
# Document: Ukraine's EU Membership Aspirations.txt, Similarity: 0.0262
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0179
#
# Results for query: 'Historical roots?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1027
# Document: Russia's History and Modern Geopolitics.txt, Similarity: 0.0842
# Historical Context of Rus...sia-Ukraine Relations.txt, Similarity: 0.0542
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0304
# Document: Russian Culture and National Identity.txt, Similarity: 0.0227
#
# Results for query: 'NATO influence?'
# Precision@5: 1.0000
# NATO's Influence on Ukrai...ne's Defense Strategy.txt, Similarity: 0.2141
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0584
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0442
# Document: evaluation_results.txt, Similarity: 0.0439
# Document: HelloRussia.txt, Similarity: 0.0420
#
# Results for query: 'Agricultural impact?'
# Precision@5: 1.0000
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.2292
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0757
# Document: evaluation_results.txt, Similarity: 0.0694
# Document: sahas_results.txt, Similarity: 0.0634
# Economic Relations Betwee...en Russia and Ukraine.txt, Similarity: 0.0553
#
# Results for query: 'Natural resources?'
# Precision@5: 1.0000
# Document: Natural Resources in Russia's Economy.txt, Similarity: 0.3894
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.3805
# Document: Ukraine's Agricultural Sector.txt, Similarity: 0.0960
# Document: sahas_results.txt, Similarity: 0.0685
# Document: evaluation_results.txt, Similarity: 0.0598
#
# Results for query: 'Russian culture?'
# Precision@5: 1.0000
# Document: The Cultural Dynamics of Ukraine.txt, Similarity: 0.1779
# Document: Russian Culture and National Identity.txt, Similarity: 0.1589
# Historical Context of Rus...sia-Ukraine Relations.txt, Similarity: 0.0353
# Document: HelloRussia.txt, Similarity: 0.0327
# Document: Ukraine's Pursuit of European Integration.txt, Similarity: 0.0294
#
# Results for query: 'Geopolitical implications?'
# Precision@5: 1.0000
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.1072
# The Role of Natural Resou...s in Russia's Economy.txt, Similarity: 0.0694
# Document: GlobalView.txt, Similarity: 0.0547
# The Cold War's Impact on ...sia-Ukraine Relations.txt, Similarity: 0.0372
# Document: Russia's History and Modern Geopolitics.txt, Similarity: 0.0343
#
# Results for query: 'Humanitarian challenges?'
# Precision@5: 1.0000
# The Impact of the Conflic... on Ukrainian Society.txt, Similarity: 0.1016
# Document: Recent Conflicts and Regional Stability.txt, Similarity: 0.0985
# Document: evaluation_results.txt, Similarity: 0.0278
# Document: HelloRussia.txt, Similarity: 0.0270
# Document: sahas_results.txt, Similarity: 0.0084
